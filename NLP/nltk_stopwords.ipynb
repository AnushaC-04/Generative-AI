# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\ANUSHA
# [nltk_data]     C\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words=stopwords.words('english')
stop_words
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
with open('D:\Gen Ai (pys)\Text Normalization\data.txt','r+') as file:
    data=file.read()

# %%
data
# Out:
# "Open file and return a stream. Raise OSError upon failure.\n\nfile is either   a text   or byte   string giving the name (and the   path\nif the file  isn't in the current  working   directory) of the file to\nbe opened or an integer file  descriptor of the file to be\nwrapped. (    If   a file descriptor is given, it is closed when   the\nreturned I/O   object is closed,   unless  closefd is set to False.)\n\n"

# %%
from nltk.tokenize import word_tokenize
token=word_tokenize(data)

# %%
print(stop_words)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
updated_tokens=[]
for word in token:
    if word not in stop_words:
        updated_tokens.append(word)
print(updated_tokens)
# Out:
# ['Open', 'file', 'return', 'stream', '.', 'Raise', 'OSError', 'upon', 'failure', '.', 'file', 'either', 'text', 'byte', 'string', 'giving', 'name', '(', 'path', 'file', "n't", 'current', 'working', 'directory', ')', 'file', 'opened', 'integer', 'file', 'descriptor', 'file', 'wrapped', '.', '(', 'If', 'file', 'descriptor', 'given', ',', 'closed', 'returned', 'I/O', 'object', 'closed', ',', 'unless', 'closefd', 'set', 'False', '.', ')']

# %%
'''if the data losses the meaning and in the chunking part wont work properly'''
# Out:
# 'if the data losses the meaning and in the chunking part wont work properly'

# %%
#directly removing the stop words from the data with using the tokenization


for word in stop_words:
    if word in data:
        data= data.replace(word,'')
print(data)
# Out:
# Open file and return a stream. Raise OSError upon failure.
#
# file is either   a text   or byte   string giving the name (and the   path
# if the file  isn't in the current  working   directory) of the file to
# be opened or an integer file  descriptor of the file to be
# wrapped. (    If   a file descriptor is given, it is closed when   the
# returned I/O   object is closed,   unless  closefd is set to False.)

# %%
### we wont be using the stop_words but spacy

# %% [markdown]
# ### sent_tokenize + stop words removal

# %%
from nltk.tokenize import sent_tokenize
tokens=sent_tokenize(data)
tokens
# Out:
# ['Open file and return a stream.',
#  'Raise OSError upon failure.',
#  "file is either   a text   or byte   string giving the name (and the   path\nif the file  isn't in the current  working   directory) of the file to\nbe opened or an integer file  descriptor of the file to be\nwrapped.",
#  '(    If   a file descriptor is given, it is closed when   the\nreturned I/O   object is closed,   unless  closefd is set to False.)']

# %%
updated_tokens=[]
for word in tokens:
    if word not in stop_words:
        updated_tokens.append(word)
print(updated_tokens)

# %%
sent=data.split('.')
sent
# Out:
# ['Open file and return a stream',
#  ' Raise OSError upon failure',
#  "\n\nfile is either   a text   or byte   string giving the name (and the   path\nif the file  isn't in the current  working   directory) of the file to\nbe opened or an integer file  descriptor of the file to be\nwrapped",
#  ' (    If   a file descriptor is given, it is closed when   the\nreturned I/O   object is closed,   unless  closefd is set to False',
#  ')\n\n']

# %% [markdown]
# **Assignment**|

# %%
nlp_sentences = [
    "The weather is beautiful today, so we decided to go for a walk in the park.",
    "I absolutely loved the movie because the storyline was engaging and emotional.",
    "The customer was unhappy with the delayed delivery and requested a refund.",
    "Artificial Intelligence is transforming industries by automating repetitive tasks.",
    "She bought a new laptop yesterday, but it stopped working this morning.",
    "Reading books every day improves vocabulary, concentration, and critical thinking.",
    "The restaurant served delicious food, and the staff were very friendly.",
    "Despite studying for several hours, he could not solve the difficult mathematics problem.",
    "My flight was canceled due to heavy rainfall, causing significant travel delays.",
    "Learning Natural Language Processing helps computers understand and generate human language."
]
