# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
word_tokens=word_tokenize("Return a tokenized copy of text, using NLTK's recommended word tokenizer (currently an improved .TreebankWordTokenizer along with .PunktSentenceTokenizer for the specified language).")

# %%
word_tokens
# Out:
# ['Return',
#  'a',
#  'tokenized',
#  'copy',
#  'of',
#  'text',
#  ',',
#  'using',
#  'NLTK',
#  "'s",
#  'recommended',
#  'word',
#  'tokenizer',
#  '(',
#  'currently',
#  'an',
#  'improved',
#  '.TreebankWordTokenizer',
#  'along',
#  'with',
#  '.PunktSentenceTokenizer',
#  'for',
#  'the',
#  'specified',
#  'language',
#  ')',
#  '.']

# %%
res='''Return a tokenized copy of text,          
'using NLTK's recommended word tokenizer currently an improved' .TreebankWordTokenizer along with .PunktSentenceTokenizer for the specified language.Tokenizers divide strings into lists of substrings. For example, tokenizers can be used to find the words and punctuation in a string'''

# %%
word=res.split(' ')
word
# Out:
# ['Return',
#  'a',
#  'tokenized',
#  'copy',
#  'of',
#  'text,',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  "\n'using",
#  "NLTK's",
#  'recommended',
#  'word',
#  'tokenizer',
#  'currently',
#  'an',
#  "improved'",
#  '.TreebankWordTokenizer',
#  'along',
#  'with',
#  '.PunktSentenceTokenizer',
#  'for',
#  'the',
#  'specified',
#  'language.Tokenizers',
#  'divide',
#  'strings',
#  'into',
#  'lists',
#  'of',
#  'substrings.',
#  'For',
#  'example,',
#  'tokenizers',
#  'can',
#  'be',
#  'used',
#  'to',
#  'find',
#  'the',
#  'words',
#  'and',
#  'punctuation',
#  'in',
#  'a',
#  'string']

# %%
sent_tokenize("Return a tokenized copy of text, using NLTK's recommended word tokenizer currently an improved .TreebankWordTokenizer along with .PunktSentenceTokenizer for the specified language.Tokenizers divide strings into lists of substrings.    For example, tokenizers can be used to find the words and punctuation in a string")
# Out:
# ["Return a tokenized copy of text, using NLTK's recommended word tokenizer currently an improved .TreebankWordTokenizer along with .PunktSentenceTokenizer for the specified language.Tokenizers divide strings into lists of substrings.",
#  'For example, tokenizers can be used to find the words and punctuation in a string']

# %%
sent=res.split('.')
sent
# Out:
# ["Return a tokenized copy of text,          \n'using NLTK's recommended word tokenizer currently an improved' ",
#  'TreebankWordTokenizer along with ',
#  'PunktSentenceTokenizer for the specified language',
#  'Tokenizers divide strings into lists of substrings',
#  ' For example, tokenizers can be used to find the words and punctuation in a string']

# %%
import  re  

# re.findall(r'\s',res)  # to get single space

# %%
re.findall(r'\s+',res) # '+' operator is used to group the pattern one or more space continueously
# re.sub(r'\s+','',res) # we should not use this it remove all the space
# Out:
# "Returnatokenizedcopyoftext,'usingNLTK'srecommendedwordtokenizercurrentlyanimproved'.TreebankWordTokenizeralongwith.PunktSentenceTokenizerforthespecifiedlanguage.Tokenizersdividestringsintolistsofsubstrings.Forexample,tokenizerscanbeusedtofindthewordsandpunctuationinastring"

# %%
re.sub(r'\s{2,}','',res)  #it remove one than one space
# Out:
# "Return a tokenized copy of text,'using NLTK's recommended word tokenizer currently an improved' .TreebankWordTokenizer along with .PunktSentenceTokenizer for the specified language.Tokenizers divide strings into lists of substrings. For example, tokenizers can be used to find the words and punctuation in a string"

# %% [markdown]
# ### to remove spl characters

# %%
re.sub(r'[^a-zA-Z0-9]','',res)
# Out:
# ''
