# %%
import contractions

# %%
s1="I'm Okey"
s2="btw ASAP I'll try to complete the task"
contractions.fix(s1)
# Out:
# 'I am Okey'

# %%
contractions.fix(s2)
# Out:
# 'by the way AS SOON AS POSSIBLE I will try to complete the task'

# %%
s3='OKaay'   # its not possible to fix this using fit 
contractions.fix(s3)
# Out:
# 'OKaay'
