# %%
import sys
print(sys.version)
import nltk
print(nltk.__version__)
from textblob import TextBlob     #we can get accuracy of 70%
# Out:
# 3.10.0 (tags/v3.10.0:b494f59, Oct  4 2021, 19:00:18) [MSC v.1929 64 bit (AMD64)]
# 3.10.0

# %%
txt='corrting the wods for txt normalization'

corrected_words=TextBlob(txt)
print(corrected_words , type(corrected_words))
# Out:
# corrting the wods for txt normalization <class 'textblob.blob.TextBlob'>
