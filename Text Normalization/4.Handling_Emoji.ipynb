# %%
import emoji

# %% [markdown]
# ### removing emojis

# %%
s='hellooo 😊'
emoji.replace_emoji(s,'')
# Out:
# 'hellooo '

# %%
s1="I'm Anusha ✌️❤️"
emoji.replace_emoji(s1,'')

# %%
## encode decode emoji using the string

# %% [markdown]
# ### To keep emoji

# %% [markdown]
# this demojize will keep the emoji but not in emoji format but in the string

# %%
s1='Heloo😂❤️😒🐽🐾🐰'
s1=emoji.demojize(s1)

# %%
s1
# Out:
# 'Heloo:face_with_tears_of_joy::red_heart::unamused_face::pig_nose::paw_prints::rabbit_face:'
