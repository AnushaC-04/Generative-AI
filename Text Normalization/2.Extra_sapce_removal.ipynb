# %% [markdown]
# ### removing mulitple space from the string/data

# %%
with open('data.txt','r') as file:
    data=file.read()
    word=data.split()
    data=' '.join(word)

# %%
#eg
s1='Anu  is smarter than  she thinks  she is'
data=s1.split()
' '.join(data)
# Out:
# 'Anu is smarter than she thinks she is'
