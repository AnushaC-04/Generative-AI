# %%
with open('data.txt','r+') as file:
    data=file.read()
print(data)
chunks=[]
fixed_size=20
overlapping=4
punctuation="\n.,"   #replace the spl char to to delimeter
for index in data:
    if index in punctuation:
        chunk=data.split(punctuation)
        chunks.append(chunk)
print(chunks)

#go learn the regularization
# Out:
# "Ml is the subset of ai which learns the pattern from the past data to predict the future. ML is fun to learn alas!
# BigData handles large amount of data it stores and process"
# [['"Ml is the subset of ai which learns the pattern from the past data to predict the future. ML is fun to learn alas!\nBigData handles large amount of data it stores and process"'], ['"Ml is the subset of ai which learns the pattern from the past data to predict the future. ML is fun to learn alas!\nBigData handles large amount of data it stores and process"']]
