# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
with open('data.txt','r+') as file:
    data=file.read()
print(type(data))
text_splitter=RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20,
    separators=["\n\n",
                 "\n"])
text_splitter.split_text(data)   #since we have string we have used split_text
# text_splitter.split_documents(data)
# Out:
# <class 'str'>
# ['"Ml is the subset of ai which learns the pattern from the past data to predict the future. ML is fun to learn alas!',
#  'BigData handles large amount of data it stores and process"']

# %% [markdown]
# ### split_text
# - it only support .text
# - it support only string
#
# ### split_document
# - it is used to read the word documents
# - will use this in langchain
